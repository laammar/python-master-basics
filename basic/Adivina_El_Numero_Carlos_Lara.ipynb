# %%
# He metido importlib porque tuve que cambiar una cosa de Funciones.py despues de haber escrito este codigo y no se actualizaba.
# Modulo con las funciones utlizadas en mi codigo del juego El Solitario. Carlos Lara Marín 77767539P
# Ademas importamos las librerias necesarias. Este programa utiliza la libreria externa "pandas" para el manejo de ficheros Excel. Aunque en clase se usara openpyxl he preferido usar pandas por comodidad y porque vi que se utilizaba en la tarea de python avanzado.
# Aunque en jupiter ya venga instalada, si no estuviera instalada se podria instalar con: pip install pandas. EL resto no requieren instalación.

import importlib
import Funciones
importlib.reload(Funciones)
while True:
    Funciones.Menu()
    Modo = Funciones.Valida(1, 4)

    if Modo == 1:
        Funciones.Solitario()
    elif Modo == 2:
        Funciones.DosJugadores()
    elif Modo == 3:
        Funciones.Estadistica()
    elif Modo == 4:
        break
# Out:
# =======================================
#                   MENU PRINCIPAL
# =======================================
# 1. Juego Solitario
# 2. Juego Dos Jugadores
# 3. Estadisticas
# 4. Salir
# =======================================
# Escriba una opción:  3
# ===== DATOS GUARDADOS EN EXCEL =====
#       Nombre       Modo Dificultad Resultado  Puntos  Intentos restantes
# 0  Carlitros  Solitario    Dificil   PERDIDA       0                   0
# 1  Carlangas        Duo    Dificil    GANADA     400                   5
#
# ===== ESTADÍSTICAS =====
# ESTADISTICA                    |  VALOR
# --------------------------------------------------
# Ganadas solitario (fácil)      | 0
# Ganadas solitario (medio)      | 0
# Ganadas solitario (difícil)    | 0
# Ganadas 2 jugadores (fácil)    | 0
# Ganadas 2 jugadores (medio)    | 0
# Ganadas 2 jugadores (difícil)  | 0
# Partidas jugadas solitario     | 0
# Partidas jugadas duo           | 0
# Partidas totales               | 0
# Puntuación total               | 0
# ==================================================
#
#
#
# =======================================
#                   MENU PRINCIPAL
# =======================================
# 1. Juego Solitario
# 2. Juego Dos Jugadores
# 3. Estadisticas
# 4. Salir
# =======================================
# Escriba una opción:  4
